# %%
import pandas as pd
import pandas as pd
import geopandas as gpd

# %%
df = pd.read_csv('data.csv')
df = df[['country', 'legatumRank2020']]
df.to_csv('health_care.csv', index = False)

# %%
gdf = gpd.read_file('countries.geojson')
gdf = gdf.rename(columns={'ADMIN': 'country'})
gdf
# Out:
#           country ISO_A3 ISO_A2  \
# 0           Aruba    ABW     AW
# 1     Afghanistan    AFG     AF
# 2          Angola    AGO     AO
# 3        Anguilla    AIA     AI
# 4         Albania    ALB     AL
# ..            ...    ...    ...
# 250         Samoa    WSM     WS
# 251         Yemen    YEM     YE
# 252  South Africa    ZAF     ZA
# 253        Zambia    ZMB     ZM
# 254      Zimbabwe    ZWE     ZW
#
#                                               geometry
# 0    MULTIPOLYGON (((-69.99694 12.57758, -69.93639 ...
# 1    MULTIPOLYGON (((71.04980 38.40866, 71.05714 38...
# 2    MULTIPOLYGON (((11.73752 -16.69258, 11.73851 -...
# 3    MULTIPOLYGON (((-63.03767 18.21296, -63.09952 ...
# 4    MULTIPOLYGON (((19.74777 42.57890, 19.74601 42...
# ..                                                 ...
# 250  MULTIPOLYGON (((-171.57002 -13.93816, -171.564...
# 251  MULTIPOLYGON (((53.30824 12.11839, 53.31027 12...
# 252  MULTIPOLYGON (((37.86378 -46.94085, 37.83644 -...
# 253  MULTIPOLYGON (((31.11984 -8.61663, 31.14102 -8...
# 254  MULTIPOLYGON (((30.01065 -15.64623, 30.05024 -...
#
# [255 rows x 4 columns]

# %%
df = pd.read_csv('file.csv')
df
# Out:
#      Unnamed: 0 iso_code continent                           country  \
# 0             0      AFG      Asia                       Afghanistan
# 1             1      ALB    Europe                           Albania
# 2             2      DZA    Africa                           Algeria
# 3             3      ASM   Oceania                    American Samoa
# 4             4      AND    Europe                           Andorra
# ..          ...      ...       ...                               ...
# 195         237      YEM      Asia                             Yemen
# 196         238      ZMB    Africa                            Zambia
# 197         239      ZWE    Africa                          Zimbabwe
# 198         240      COD    Africa  Democratic Republic of the Congo
# 199         241      COG    Africa                 Republic of Congo
#
#      total_cases  total_deaths  median_age  population     area Density  \
# 0        52330.0        2189.0        18.6  41128772.0   647500    48,0
# 1        57146.0        1170.0        38.0   2842318.0    28748   124,6
# 2        99311.0        2751.0        29.1  44903228.0  2381740    13,8
# 3            NaN           NaN         NaN     44295.0      199   290,4
# 4         7983.0          84.0         NaN     79843.0      468   152,1
# ..           ...           ...         ...         ...      ...     ...
# 195       2100.0         611.0        20.3  33696612.0   527970    40,6
# 196      20462.0         386.0        17.7  20017670.0   752614    15,3
# 197      13625.0         360.0        19.6  16320539.0   390580    31,3
# 198      17657.0         591.0        17.0  99010216.0  2345410    26,7
# 199       6431.0         100.0        19.0   5970430.0   342000    10,8
#
#     netmigraration morality      GDP
# 0            23,06   163,07    700.0
# 1            -4,93    21,52   4500.0
# 2            -0,39       31   6000.0
# 3           -20,71     9,27   8000.0
# 4              6,6     4,05  19000.0
# ..             ...      ...      ...
# 195              0     61,5    800.0
# 196              0    88,29    800.0
# 197              0    67,69   1900.0
# 198              0    94,69    700.0
# 199          -0,17    93,86    700.0
#
# [200 rows x 13 columns]

# %%
country_ids = df['country'].unique()
final_gdf = gdf[gdf['country'].isin(country_ids)]
final_gdf = final_gdf.reset_index(drop=True)
final_gdf = final_gdf.drop('ISO_A2', axis=1)
final_gdf = final_gdf.drop('ISO_A3', axis=1)

final_gdf
# Out:
#           country                                           geometry
# 0           Aruba  MULTIPOLYGON (((-69.99694 12.57758, -69.93639 ...
# 1     Afghanistan  MULTIPOLYGON (((71.04980 38.40866, 71.05714 38...
# 2          Angola  MULTIPOLYGON (((11.73752 -16.69258, 11.73851 -...
# 3        Anguilla  MULTIPOLYGON (((-63.03767 18.21296, -63.09952 ...
# 4         Albania  MULTIPOLYGON (((19.74777 42.57890, 19.74601 42...
# ..            ...                                                ...
# 188         Samoa  MULTIPOLYGON (((-171.57002 -13.93816, -171.564...
# 189         Yemen  MULTIPOLYGON (((53.30824 12.11839, 53.31027 12...
# 190  South Africa  MULTIPOLYGON (((37.86378 -46.94085, 37.83644 -...
# 191        Zambia  MULTIPOLYGON (((31.11984 -8.61663, 31.14102 -8...
# 192      Zimbabwe  MULTIPOLYGON (((30.01065 -15.64623, 30.05024 -...
#
# [193 rows x 2 columns]

# %%
health_df = pd.read_csv('health_care.csv')

# %%
merged_gdf = final_gdf.merge(df, left_on='country', right_on='country', how='inner')
merged_gdf = merged_gdf.drop('Unnamed: 0', axis=1)
perc = []
for i in range(0, len(merged_gdf["continent"])):
    num = (merged_gdf["total_deaths"][i] / merged_gdf["population"][i]) * 100
    perc.append(f"{num}%")
merged_gdf["percentage"] = perc
merged_gdf = merged_gdf.merge(health_df, how='left', left_on='country', right_on='country')
merged_gdf.fillna(value={'column_with_missing_values': None}, inplace=True)
merged_gdf = merged_gdf.rename(columns={'legatumRank2020': 'health_care'})
# print(set(merged_gdf['country'])-set(health_df['country']))
merged_gdf
# Out:
#           country                                           geometry iso_code  \
# 0           Aruba  MULTIPOLYGON (((-69.99694 12.57758, -69.93639 ...      ABW
# 1     Afghanistan  MULTIPOLYGON (((71.04980 38.40866, 71.05714 38...      AFG
# 2          Angola  MULTIPOLYGON (((11.73752 -16.69258, 11.73851 -...      AGO
# 3        Anguilla  MULTIPOLYGON (((-63.03767 18.21296, -63.09952 ...      AIA
# 4         Albania  MULTIPOLYGON (((19.74777 42.57890, 19.74601 42...      ALB
# ..            ...                                                ...      ...
# 188         Samoa  MULTIPOLYGON (((-171.57002 -13.93816, -171.564...      WSM
# 189         Yemen  MULTIPOLYGON (((53.30824 12.11839, 53.31027 12...      YEM
# 190  South Africa  MULTIPOLYGON (((37.86378 -46.94085, 37.83644 -...      ZAF
# 191        Zambia  MULTIPOLYGON (((31.11984 -8.61663, 31.14102 -8...      ZMB
# 192      Zimbabwe  MULTIPOLYGON (((30.01065 -15.64623, 30.05024 -...      ZWE
#
#          continent  total_cases  total_deaths  median_age  population  \
# 0    North America       5373.0          49.0        41.2    106459.0
# 1             Asia      52330.0        2189.0        18.6  41128772.0
# 2           Africa      17433.0         405.0        16.8  35588996.0
# 3    North America         13.0           NaN         NaN     15877.0
# 4           Europe      57146.0        1170.0        38.0   2842318.0
# ..             ...          ...           ...         ...         ...
# 188        Oceania          1.0           NaN        22.0    222390.0
# 189           Asia       2100.0         611.0        20.3  33696612.0
# 190         Africa    1039161.0       28033.0        27.3  59893884.0
# 191         Africa      20462.0         386.0        17.7  20017670.0
# 192         Africa      13625.0         360.0        19.6  16320539.0
#
#         area Density netmigraration morality      GDP              percentage  \
# 0        193   372,5              0     5,89  28000.0    0.04602710902788867%
# 1     647500    48,0          23,06   163,07    700.0   0.005322308188535267%
# 2    1246700     9,7              0   191,19   1900.0  0.0011379922041071346%
# 3        102   132,1          10,76    21,03   8600.0                    nan%
# 4      28748   124,6          -4,93    21,52   4500.0    0.04116358549606342%
# ..       ...     ...            ...      ...      ...                     ...
# 188     2944    60,1          -11,7    27,71   5600.0                    nan%
# 189   527970    40,6              0     61,5    800.0    0.00181323867218461%
# 190  1219912    36,2          -0,29    61,81  10700.0    0.04680444500810801%
# 191   752614    15,3              0    88,29    800.0  0.0019282963501746208%
# 192   390580    31,3              0    67,69   1900.0   0.002205809501757264%
#
#      health_care
# 0            NaN
# 1          162.0
# 2          156.0
# 3            NaN
# 4           67.0
# ..           ...
# 188          NaN
# 189        165.0
# 190         87.0
# 191        123.0
# 192        143.0
#
# [193 rows x 15 columns]

# %%
merged_gdf.plot(figsize=(20, 10))
# Out:
# <AxesSubplot: >
